# %% [markdown]
# <a href="https://colab.research.google.com/github/sunjin7725/SJ-SOLAR-10.7b-DPO/blob/main/Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import torch

from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'SJ-Donald/SJ-SOLAR-10.7b-DPO'

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/679 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# ...

# %%
conversation = [ {'role': 'user', 'content': '초급자에게 적당한 천체 망원경 추천해줘'}
            ]

prompt = tokenizer.apply_chat_template(conversation, tokenize=False, add_generation_prompt=True)

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, use_cache=True, max_length=4096)
output_text = tokenizer.decode(outputs[0])
print(output_text)
# Out:
# <s> ### User:
# 초급자에게  적당한  천체 망 원경 추천 해줘
#
# ### Assistant:
# 초급자에게 적당한 천체망원경을 추천하기 위해서는 몇가지 요소를 고려해야 합니다. 아래 는 초급자에게 적합한 망원경을 선택하는데 도움이 될 몇가지 기준입니다 .
#
# 1. 가격: 망원경의 가격은 100달러에서 1000달러 이상까지 다양합니다. 초급자에게 적합한 망원경은 100달러에서 300달러 사이의 가격대에 있을 것입니다.
#
# 2. 사용 자 친 화성: 망원경을 사용하기 위해서는 별도의 학위가 필요하지 않습니다. 초급자에게 적합한 망원경은 사용하기 쉽 고 조정하기 쉬 워야합니다.
#
# 3. 광 학: 망원경의 광 학은 망원경의 성능에 큰 영향을 미칩니다. 초급자에게 적합한 망원경은 보통 100mm에서 150mm의 아포크롬 아티팩트 없는  (ACO) 렌즈 를 사용합니다.
#
# 4. 안정성: 망원경의 안정성은 관측 할 때 이미지를 더 명확하게 보여줍니다. 초급자에게 적합한 망원경은 삼 각대와 EQ (Equatorial) 거울을 갖춰 야합니다.
#
# 5. 추가 기능: 망원경의 추가 기능은 관측 을 더욱 더 즐겁게 만들 수 있습니다 . 초급자에게 적합한 망원경은 보통 휴 대용 케이스, 렌즈 커버, 렌즈 클리 너, 그리고  망원경의 위치 를 추적하는  EQ 거울을 갖 추고 있습니다 .
#
# 아래 는 초급자에게 적합한 망원경의 몇가지 예입니다.
#
# 1. Celestron AstroMaster 130EQ: 130mm 렌즈 와 EQ 거울을 갖춘 이 망원경은 100달러 에서 300달러 사이의 가격대에 있습니다 .
#
# 2. Orion StarBlast 4.5 EQ: 4.5인치 의 렌즈 와 EQ 거울을 갖춘 이 망원경은 100달러 에서 300달러 사이의 가격대에 있습니다 .
#
# 3. Celestron NexStar 5SE: 127mm 렌즈와  EQ 거울을 갖춘 이 망원경은 100달러 에서 300달러 사이의 가격대에 있습니다 .
#
# ...
